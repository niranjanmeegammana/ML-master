# %% [markdown]
# # Multiple Regression
# Multiple regression takes more than one independent valueto predict a value.

# %% [markdown]
# #Data Frame

# %%
import pandas as pd
d=[1,2,3,4,5]
df=pd.DataFrame(d)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
import pandas as pd
data = {'col1': [1, 2], 'col2': [3, 4]}
df = pd.DataFrame(data)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
# intialise data of lists.
data = {'Name':['Ama', 'Bima', 'Cima', 'Duma'],
        'Age':[20, 21, 19, 18]}
 
# Create DataFrame
df = pd.DataFrame(data)
 
# Print the output.
print(df)
# Out:
#    Name  Age
# 0   Ama   20
# 1  Bima   21
# 2  Cima   19
# 3  Duma   18

# %%
url="https://raw.githubusercontent.com/ShilpaSayuraML/ML-classification/main/data/cars_data.csv"
df=pd.read_csv(url)
df.head(10)
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo    1000     790   99
# 1  Mitsubishi  Space Star    1200    1160   95
# 2       Skoda      Citigo    1000     929   95
# 3        Fiat         500     900     865   90
# 4        Mini      Cooper    1500    1140  105
# 5          VW         Up!    1000     929  105
# 6       Skoda       Fabia    1400    1109   90
# 7    Mercedes     A-Class    1500    1365   92
# 8        Ford      Fiesta    1500    1112   98
# 9        Audi          A1    1600    1150   99

# %%
#create model
from sklearn import linear_model

X = df[['Weight', 'Volume']]
y = df['CO2']

regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression()

# %%
#predict the CO2 emission of a car where the weight is 2300kg, and the volume is 1300cm3:
car1=[2300,1300]
predictedCO2 = regr.predict([car1])
print(predictedCO2)
# Out:
# [107.2087328]
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# 107.2087328 + (1000 * 0.00755095) = 114.75968

# %% [markdown]
# release approximately 107 grams of CO2 for every kilometer it drives.

# %% [markdown]
# #Coefficient
# The coefficient is a factor that describes the relationship with an unknown variable.
#
# Example: if x is a variable, then 2x is x two times.
# x is the unknown variable, and the number 2 is the coefficient.

# %%
print(regr.coef_)
# Out:
# [0.00755095 0.00780526]

# %% [markdown]
# The result array represents the coefficient values of weight and volume.
#
# Weight: 0.00755095
# Volume: 0.00780526
#
# These values tell us that if the weight increase by 1kg, the CO2 emission increases by 0.00755095g.
#
# And if the engine size (Volume) increases by 1 cm3, the CO2 emission increases by 0.00780526 g.
#
#
# #What if we increase the weight with 1000kg?

# %%
predictedCO2 = regr.predict([[3300, 1300]])

print(predictedCO2)
# Out:
# [114.75968007]
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Scale Features
# When data has different values, or different measurement units, it can be difficult to compare them. What is kilograms compared to meters? Or altitude compared to time?
#
# The answer to this problem is scaling.
#
# We can scale data into new values that are easier to compare.

# %%
import pandas
from sklearn import linear_model

X = df[['Weight', 'Volume']]
print(X)
# Out:
#     Weight  Volume
# 0      790    1000
# 1     1160    1200
# 2      929    1000
# 3      865     900
# 4     1140    1500
# 5      929    1000
# 6     1109    1400
# 7     1365    1500
# 8     1112    1500
# 9     1150    1600
# 10     980    1100
# 11     990    1300
# 12    1112    1000
# 13    1252    1600
# 14    1326    1600
# 15    1330    1600
# 16    1365    1600
# 17    1280    2200
# 18    1119    1600
# 19    1328    2000
# 20    1584    1600
# 21    1428    2000
# 22    1365    2100
# 23    1415    1600
# 24    1415    2000
# 25    1465    1500
# 26    1490    2000
# 27    1725    2000
# 28    1523    1600
# 29    1705    2000
# 30    1605    2100
# 31    1746    2000
# 32    1235    1600
# 33    1390    1600
# 34    1405    1600
# 35    1395    2500

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

scaledX = scale.fit_transform(X)
print(scaledX)
# Out:
# [[-2.10389253 -1.59336644]
#  [-0.55407235 -1.07190106]
#  [-1.52166278 -1.59336644]
#  [-1.78973979 -1.85409913]
#  [-0.63784641 -0.28970299]
#  [-1.52166278 -1.59336644]
#  [-0.76769621 -0.55043568]
#  [ 0.3046118  -0.28970299]
#  [-0.7551301  -0.28970299]
#  [-0.59595938 -0.0289703 ]
#  [-1.30803892 -1.33263375]
#  [-1.26615189 -0.81116837]
#  [-0.7551301  -1.59336644]
#  [-0.16871166 -0.0289703 ]
#  [ 0.14125238 -0.0289703 ]
#  [ 0.15800719 -0.0289703 ]
#  [ 0.3046118  -0.0289703 ]
#  [-0.05142797  1.53542584]
#  [-0.72580918 -0.0289703 ]
#  [ 0.14962979  1.01396046]
#  [ 1.2219378  -0.0289703 ]
#  [ 0.5685001   1.01396046]
#  [ 0.3046118   1.27469315]
#  [ 0.51404696 -0.0289703 ]
#  [ 0.51404696  1.01396046]
#  [ 0.72348212 -0.28970299]
#  [ 0.8281997   1.01396046]
#  [ 1.81254495  1.01396046]
#  [ 0.96642691 -0.0289703 ]
#  [ 1.72877089  1.01396046]
#  [ 1.30990057  1.27469315]
#  [ 1.90050772  1.01396046]
#  [-0.23991961 -0.0289703 ]
#  [ 0.40932938 -0.0289703 ]
# ...

# %%
print(X[:1])
print(scaledX[:1][0])
# Out:
#    Weight  Volume
# 0     790    1000
# [-2.10389253 -1.59336644]

# %%
regr = linear_model.LinearRegression()
regr.fit(scaledX, y)

scaled = scale.transform([[2300, 1.3]])

predictedCO2 = regr.predict([scaled[0]])
print(predictedCO2)
# Out:
# [97.07204485]
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
