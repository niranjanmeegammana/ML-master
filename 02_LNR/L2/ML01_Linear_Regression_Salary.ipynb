# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
# Read Dataset
url="https://raw.githubusercontent.com/ShilpaSayuraML/ML-classification/main/data/Salary_Data.csv"

salary_data=pd.read_csv(url)
#Display Head of the dataset
salary_data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
# Define X & Y Variables
X = salary_data.iloc[:,:-1].values
Y = salary_data.iloc[:,1].values

# %%
X[0:5]
# Out:
# array([[1.1],
#        [1.3],
#        [1.5],
#        [2. ],
#        [2.2]])

# %%
Y[0:5]
# Out:
# array([39343, 46205, 37731, 43525, 39891])

# %%
#Split Data s.t. test_size of 1/3 and train size of 2/3 from OG Dataset
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=1/3)

# %%
#Init Linear Regression & Predict on Test
model2 = LinearRegression()
model2.fit(X_train,Y_train)
values = model2.predict(X_test)

# %%
#Plot Train Data
plt.scatter(X_train,Y_train,color="blue")
plt.plot(X_train,model2.predict(X_train),color='red')
plt.title("No. of years Exp ~ Salary for training data")
plt.xlabel("YearsExp")
plt.ylabel("Salary")
plt.show()

# %%
#Plot Test Data
plt.scatter(X_test,Y_test,color="blue")
plt.plot(X_test,model2.predict(X_test),color='red')
plt.title("No. of years Exp ~ Salary for Testing data")
plt.xlabel("YearsExp")
plt.ylabel("Salary")
plt.show()

# %%
# Check Accuracy Score
print('Mean Squared Error',metrics.mean_squared_error(Y_test,values))
# Out:
# Mean Squared Error 25770512.303692043

# %%
model2.predict([[8.5]])
# Out:
# array([106855.17815274])
