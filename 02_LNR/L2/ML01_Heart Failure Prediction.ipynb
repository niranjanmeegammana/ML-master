# %% [markdown]
# # Preparation

# %%
# Import libraries
## Basic libs
import pandas as pd
import numpy as np
import warnings
## Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Configure libraries
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (10, 10)
plt.style.use('seaborn')

# !pip install xgboost --upgrade
import xgboost
print(xgboost.__version__)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.8/dist-packages (0.90)
# Collecting xgboost
#   Downloading xgboost-1.7.3-py3-none-manylinux2014_x86_64.whl (193.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 MB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from xgboost) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from xgboost) (1.21.6)
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
# Successfully installed xgboost-1.7.3
# 1.7.3

# %%
# Load dataset
url="https://raw.githubusercontent.com/ShilpaSayuraML/data-science-mastsr/master/data/heart_failure.csv"

df = pd.read_csv(url)
print('Shape of dataframe:', df.shape)
df.head()
# Out:
# Shape of dataframe: (299, 13)
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %%
df['DEATH_EVENT'].value_counts()
# Out:
# 0    203
# 1     96
# Name: DEATH_EVENT, dtype: int64

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
corr = df.corr()
ax, fig = plt.subplots(figsize=(15,15))
sns.heatmap(corr, vmin=-1, cmap='coolwarm', annot=True)
plt.show()

# %%
corr[abs(corr['DEATH_EVENT']) > 0.1]['DEATH_EVENT']
# Out:
# age                  0.253729
# ejection_fraction   -0.268603
# serum_creatinine     0.294278
# serum_sodium        -0.195204
# time                -0.526964
# DEATH_EVENT          1.000000
# Name: DEATH_EVENT, dtype: float64

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Basic Mode

# %% [markdown]
# ### Training Model

# %%
# Select feature
x_basic = df[['age', 'anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking']]
# x_basic = df[['age', 'anaemia', 'sex', 'high_blood_pressure', 'smoking']]
y_basic = df['DEATH_EVENT']

# Scale data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_basic_scaled = x_basic.copy()
x_basic_scaled[['age']] = scaler.fit_transform(x_basic[['age']])

# Split dataset
from sklearn.model_selection import train_test_split
x_basic_train, x_basic_test, y_basic_train, y_basic_test = train_test_split(x_basic_scaled, y_basic, random_state=1, test_size=0.2)

# Train model
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score, accuracy_score, plot_confusion_matrix
from sklearn.model_selection import StratifiedKFold, GridSearchCV

# params = {
#         'min_child_weight': [1, 5, 10],
#         'gamma': [0.5, 1, 1.5, 2, 5],
#         'subsample': [0.6, 0.8, 1.0],
#         'colsample_bytree': [0.6, 0.8, 1.0],
#         'max_depth': [3, 4, 5]
#         }
params = {
        'min_child_weight': [1],
        'gamma': [5],
        'subsample': [0.6],
        'colsample_bytree': [1.0],
        'max_depth': [3]
        }

xgb = XGBClassifier(learning_rate=0.01, n_estimators=1000, objective='binary:logistic')

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

grid_basic = GridSearchCV(estimator=xgb, param_grid=params, n_jobs=-1,
                          cv=skf.split(x_basic_train, y_basic_train), verbose=0)

grid_basic.fit(x_basic_train, y_basic_train, early_stopping_rounds=30, eval_set=[(x_basic_test, y_basic_test)])
# Out:
# [0]	validation_0-logloss:0.69038
# [1]	validation_0-logloss:0.68810
# [2]	validation_0-logloss:0.68617
# [3]	validation_0-logloss:0.68361
# [4]	validation_0-logloss:0.68145
# [5]	validation_0-logloss:0.67942
# [6]	validation_0-logloss:0.67783
# [7]	validation_0-logloss:0.67642
# [8]	validation_0-logloss:0.67404
# [9]	validation_0-logloss:0.67230
# [10]	validation_0-logloss:0.67025
# [11]	validation_0-logloss:0.66799
# [12]	validation_0-logloss:0.66624
# [13]	validation_0-logloss:0.66429
# [14]	validation_0-logloss:0.66223
# [15]	validation_0-logloss:0.66078
# [16]	validation_0-logloss:0.65851
# [17]	validation_0-logloss:0.65685
# [18]	validation_0-logloss:0.65551
# [19]	validation_0-logloss:0.65344
# [20]	validation_0-logloss:0.65163
# [21]	validation_0-logloss:0.64961
# [22]	validation_0-logloss:0.64788
# [23]	validation_0-logloss:0.64586
# [24]	validation_0-logloss:0.64415
# [25]	validation_0-logloss:0.64252
# [26]	validation_0-logloss:0.64130
# [27]	validation_0-logloss:0.64045
# [28]	validation_0-logloss:0.63869
# [29]	validation_0-logloss:0.63657
# [30]	validation_0-logloss:0.63527
# [31]	validation_0-logloss:0.63340
# [32]	validation_0-logloss:0.63178
# [33]	validation_0-logloss:0.63004
# [34]	validation_0-logloss:0.62920
# [35]	validation_0-logloss:0.62760
# [36]	validation_0-logloss:0.62639
# [37]	validation_0-logloss:0.62480
# [38]	validation_0-logloss:0.62362
# [39]	validation_0-logloss:0.62209
# [40]	validation_0-logloss:0.62069
# [41]	validation_0-logloss:0.61980
# [42]	validation_0-logloss:0.61858
# [43]	validation_0-logloss:0.61761
# [44]	validation_0-logloss:0.61586
# [45]	validation_0-logloss:0.61466
# [46]	validation_0-logloss:0.61382
# [47]	validation_0-logloss:0.61262
# [48]	validation_0-logloss:0.61151
# [49]	validation_0-logloss:0.61012
# [50]	validation_0-logloss:0.60909
# [51]	validation_0-logloss:0.60762
# [52]	validation_0-logloss:0.60612
# [53]	validation_0-logloss:0.60536
# [54]	validation_0-logloss:0.60384
# [55]	validation_0-logloss:0.60253
# [56]	validation_0-logloss:0.60178
# [57]	validation_0-logloss:0.60165
# [58]	validation_0-logloss:0.60110
# [59]	validation_0-logloss:0.60007
# [60]	validation_0-logloss:0.59881
# [61]	validation_0-logloss:0.59808
# [62]	validation_0-logloss:0.59668
# [63]	validation_0-logloss:0.59594
# [64]	validation_0-logloss:0.59535
# [65]	validation_0-logloss:0.59484
# [66]	validation_0-logloss:0.59430
# [67]	validation_0-logloss:0.59284
# [68]	validation_0-logloss:0.59254
# [69]	validation_0-logloss:0.59226
# [70]	validation_0-logloss:0.59191
# [71]	validation_0-logloss:0.59124
# [72]	validation_0-logloss:0.59066
# [73]	validation_0-logloss:0.59022
# [74]	validation_0-logloss:0.58918
# [75]	validation_0-logloss:0.58810
# [76]	validation_0-logloss:0.58721
# [77]	validation_0-logloss:0.58616
# [78]	validation_0-logloss:0.58478
# [79]	validation_0-logloss:0.58415
# [80]	validation_0-logloss:0.58316
# [81]	validation_0-logloss:0.58285
# [82]	validation_0-logloss:0.58264
# [83]	validation_0-logloss:0.58212
# [84]	validation_0-logloss:0.58135
# [85]	validation_0-logloss:0.58081
# [86]	validation_0-logloss:0.58049
# [87]	validation_0-logloss:0.57928
# [88]	validation_0-logloss:0.57821
# [89]	validation_0-logloss:0.57765
# [90]	validation_0-logloss:0.57731
# [91]	validation_0-logloss:0.57695
# [92]	validation_0-logloss:0.57590
# [93]	validation_0-logloss:0.57496
# [94]	validation_0-logloss:0.57468
# [95]	validation_0-logloss:0.57432
# [96]	validation_0-logloss:0.57347
# [97]	validation_0-logloss:0.57290
# [98]	validation_0-logloss:0.57268
# [99]	validation_0-logloss:0.57189
# [100]	validation_0-logloss:0.57126
# [101]	validation_0-logloss:0.57080
# [102]	validation_0-logloss:0.57053
# [103]	validation_0-logloss:0.57000
# [104]	validation_0-logloss:0.56943
# [105]	validation_0-logloss:0.56925
# [106]	validation_0-logloss:0.56874
# [107]	validation_0-logloss:0.56854
# [108]	validation_0-logloss:0.56778
# [109]	validation_0-logloss:0.56734
# [110]	validation_0-logloss:0.56609
# [111]	validation_0-logloss:0.56576
# [112]	validation_0-logloss:0.56536
# [113]	validation_0-logloss:0.56447
# [114]	validation_0-logloss:0.56430
# [115]	validation_0-logloss:0.56365
# [116]	validation_0-logloss:0.56334
# [117]	validation_0-logloss:0.56253
# [118]	validation_0-logloss:0.56192
# [119]	validation_0-logloss:0.56139
# [120]	validation_0-logloss:0.56103
# [121]	validation_0-logloss:0.56099
# [122]	validation_0-logloss:0.56066
# [123]	validation_0-logloss:0.56015
# [124]	validation_0-logloss:0.55965
# [125]	validation_0-logloss:0.55927
# [126]	validation_0-logloss:0.55860
# [127]	validation_0-logloss:0.55846
# [128]	validation_0-logloss:0.55833
# [129]	validation_0-logloss:0.55834
# [130]	validation_0-logloss:0.55799
# [131]	validation_0-logloss:0.55724
# [132]	validation_0-logloss:0.55608
# [133]	validation_0-logloss:0.55560
# [134]	validation_0-logloss:0.55524
# [135]	validation_0-logloss:0.55481
# [136]	validation_0-logloss:0.55475
# [137]	validation_0-logloss:0.55448
# [138]	validation_0-logloss:0.55422
# [139]	validation_0-logloss:0.55405
# [140]	validation_0-logloss:0.55399
# [141]	validation_0-logloss:0.55365
# [142]	validation_0-logloss:0.55342
# [143]	validation_0-logloss:0.55323
# [144]	validation_0-logloss:0.55317
# [145]	validation_0-logloss:0.55275
# [146]	validation_0-logloss:0.55230
# [147]	validation_0-logloss:0.55207
# [148]	validation_0-logloss:0.55141
# [149]	validation_0-logloss:0.55113
# [150]	validation_0-logloss:0.55099
# [151]	validation_0-logloss:0.55065
# [152]	validation_0-logloss:0.55058
# [153]	validation_0-logloss:0.55031
# [154]	validation_0-logloss:0.54968
# [155]	validation_0-logloss:0.54948
# [156]	validation_0-logloss:0.54962
# [157]	validation_0-logloss:0.54960
# [158]	validation_0-logloss:0.54925
# [159]	validation_0-logloss:0.54898
# [160]	validation_0-logloss:0.54891
# [161]	validation_0-logloss:0.54864
# [162]	validation_0-logloss:0.54861
# [163]	validation_0-logloss:0.54865
# [164]	validation_0-logloss:0.54869
# [165]	validation_0-logloss:0.54846
# [166]	validation_0-logloss:0.54855
# [167]	validation_0-logloss:0.54854
# [168]	validation_0-logloss:0.54859
# [169]	validation_0-logloss:0.54850
# [170]	validation_0-logloss:0.54830
# [171]	validation_0-logloss:0.54820
# [172]	validation_0-logloss:0.54791
# [173]	validation_0-logloss:0.54799
# [174]	validation_0-logloss:0.54765
# [175]	validation_0-logloss:0.54750
# [176]	validation_0-logloss:0.54677
# [177]	validation_0-logloss:0.54653
# [178]	validation_0-logloss:0.54644
# [179]	validation_0-logloss:0.54626
# [180]	validation_0-logloss:0.54617
# [181]	validation_0-logloss:0.54577
# [182]	validation_0-logloss:0.54557
# [183]	validation_0-logloss:0.54526
# [184]	validation_0-logloss:0.54508
# [185]	validation_0-logloss:0.54478
# [186]	validation_0-logloss:0.54472
# [187]	validation_0-logloss:0.54460
# [188]	validation_0-logloss:0.54446
# [189]	validation_0-logloss:0.54421
# [190]	validation_0-logloss:0.54413
# [191]	validation_0-logloss:0.54373
# [192]	validation_0-logloss:0.54365
# [193]	validation_0-logloss:0.54370
# [194]	validation_0-logloss:0.54354
# [195]	validation_0-logloss:0.54352
# [196]	validation_0-logloss:0.54297
# [197]	validation_0-logloss:0.54286
# [198]	validation_0-logloss:0.54272
# [199]	validation_0-logloss:0.54274
# [200]	validation_0-logloss:0.54239
# [201]	validation_0-logloss:0.54220
# [202]	validation_0-logloss:0.54198
# [203]	validation_0-logloss:0.54187
# [204]	validation_0-logloss:0.54191
# [205]	validation_0-logloss:0.54175
# [206]	validation_0-logloss:0.54154
# [207]	validation_0-logloss:0.54104
# [208]	validation_0-logloss:0.54087
# [209]	validation_0-logloss:0.54077
# [210]	validation_0-logloss:0.54053
# [211]	validation_0-logloss:0.54045
# [212]	validation_0-logloss:0.54023
# [213]	validation_0-logloss:0.53996
# [214]	validation_0-logloss:0.53976
# [215]	validation_0-logloss:0.53926
# [216]	validation_0-logloss:0.53904
# [217]	validation_0-logloss:0.53870
# [218]	validation_0-logloss:0.53885
# [219]	validation_0-logloss:0.53877
# [220]	validation_0-logloss:0.53884
# [221]	validation_0-logloss:0.53886
# [222]	validation_0-logloss:0.53893
# [223]	validation_0-logloss:0.53892
# [224]	validation_0-logloss:0.53851
# [225]	validation_0-logloss:0.53822
# [226]	validation_0-logloss:0.53808
# [227]	validation_0-logloss:0.53836
# [228]	validation_0-logloss:0.53825
# [229]	validation_0-logloss:0.53830
# [230]	validation_0-logloss:0.53817
# [231]	validation_0-logloss:0.53821
# [232]	validation_0-logloss:0.53789
# [233]	validation_0-logloss:0.53786
# [234]	validation_0-logloss:0.53805
# [235]	validation_0-logloss:0.53780
# [236]	validation_0-logloss:0.53797
# [237]	validation_0-logloss:0.53798
# [238]	validation_0-logloss:0.53795
# [239]	validation_0-logloss:0.53797
# [240]	validation_0-logloss:0.53733
# [241]	validation_0-logloss:0.53751
# [242]	validation_0-logloss:0.53746
# [243]	validation_0-logloss:0.53727
# [244]	validation_0-logloss:0.53734
# [245]	validation_0-logloss:0.53731
# [246]	validation_0-logloss:0.53724
# [247]	validation_0-logloss:0.53711
# [248]	validation_0-logloss:0.53702
# [249]	validation_0-logloss:0.53687
# [250]	validation_0-logloss:0.53674
# [251]	validation_0-logloss:0.53648
# [252]	validation_0-logloss:0.53594
# [253]	validation_0-logloss:0.53585
# [254]	validation_0-logloss:0.53550
# [255]	validation_0-logloss:0.53487
# [256]	validation_0-logloss:0.53475
# [257]	validation_0-logloss:0.53450
# [258]	validation_0-logloss:0.53453
# [259]	validation_0-logloss:0.53456
# [260]	validation_0-logloss:0.53474
# [261]	validation_0-logloss:0.53451
# [262]	validation_0-logloss:0.53434
# [263]	validation_0-logloss:0.53416
# [264]	validation_0-logloss:0.53405
# [265]	validation_0-logloss:0.53394
# [266]	validation_0-logloss:0.53385
# [267]	validation_0-logloss:0.53341
# [268]	validation_0-logloss:0.53339
# [269]	validation_0-logloss:0.53346
# [270]	validation_0-logloss:0.53318
# [271]	validation_0-logloss:0.53322
# [272]	validation_0-logloss:0.53290
# [273]	validation_0-logloss:0.53304
# [274]	validation_0-logloss:0.53297
# [275]	validation_0-logloss:0.53272
# [276]	validation_0-logloss:0.53272
# [277]	validation_0-logloss:0.53259
# [278]	validation_0-logloss:0.53260
# [279]	validation_0-logloss:0.53211
# [280]	validation_0-logloss:0.53214
# [281]	validation_0-logloss:0.53213
# [282]	validation_0-logloss:0.53222
# [283]	validation_0-logloss:0.53219
# [284]	validation_0-logloss:0.53221
# [285]	validation_0-logloss:0.53238
# [286]	validation_0-logloss:0.53233
# [287]	validation_0-logloss:0.53205
# [288]	validation_0-logloss:0.53195
# [289]	validation_0-logloss:0.53166
# [290]	validation_0-logloss:0.53175
# [291]	validation_0-logloss:0.53133
# [292]	validation_0-logloss:0.53108
# [293]	validation_0-logloss:0.53107
# [294]	validation_0-logloss:0.53089
# [295]	validation_0-logloss:0.53085
# [296]	validation_0-logloss:0.53065
# [297]	validation_0-logloss:0.53065
# [298]	validation_0-logloss:0.53074
# [299]	validation_0-logloss:0.53062
# [300]	validation_0-logloss:0.53064
# [301]	validation_0-logloss:0.53083
# [302]	validation_0-logloss:0.53016
# [303]	validation_0-logloss:0.53012
# [304]	validation_0-logloss:0.53015
# [305]	validation_0-logloss:0.53032
# [306]	validation_0-logloss:0.53027
# [307]	validation_0-logloss:0.53009
# [308]	validation_0-logloss:0.52971
# [309]	validation_0-logloss:0.52973
# [310]	validation_0-logloss:0.52972
# [311]	validation_0-logloss:0.52980
# [312]	validation_0-logloss:0.52983
# [313]	validation_0-logloss:0.52980
# [314]	validation_0-logloss:0.52966
# [315]	validation_0-logloss:0.52969
# [316]	validation_0-logloss:0.52975
# [317]	validation_0-logloss:0.52997
# [318]	validation_0-logloss:0.53013
# [319]	validation_0-logloss:0.53012
# [320]	validation_0-logloss:0.52990
# [321]	validation_0-logloss:0.52964
# [322]	validation_0-logloss:0.52949
# [323]	validation_0-logloss:0.52980
# [324]	validation_0-logloss:0.52907
# [325]	validation_0-logloss:0.52890
# [326]	validation_0-logloss:0.52875
# [327]	validation_0-logloss:0.52866
# [328]	validation_0-logloss:0.52850
# [329]	validation_0-logloss:0.52858
# [330]	validation_0-logloss:0.52873
# [331]	validation_0-logloss:0.52883
# [332]	validation_0-logloss:0.52878
# [333]	validation_0-logloss:0.52880
# [334]	validation_0-logloss:0.52891
# [335]	validation_0-logloss:0.52895
# [336]	validation_0-logloss:0.52889
# [337]	validation_0-logloss:0.52883
# [338]	validation_0-logloss:0.52881
# [339]	validation_0-logloss:0.52895
# [340]	validation_0-logloss:0.52898
# [341]	validation_0-logloss:0.52894
# [342]	validation_0-logloss:0.52910
# [343]	validation_0-logloss:0.52904
# [344]	validation_0-logloss:0.52891
# [345]	validation_0-logloss:0.52887
# [346]	validation_0-logloss:0.52864
# [347]	validation_0-logloss:0.52816
# [348]	validation_0-logloss:0.52825
# [349]	validation_0-logloss:0.52795
# [350]	validation_0-logloss:0.52783
# [351]	validation_0-logloss:0.52780
# [352]	validation_0-logloss:0.52765
# [353]	validation_0-logloss:0.52747
# [354]	validation_0-logloss:0.52727
# [355]	validation_0-logloss:0.52668
# [356]	validation_0-logloss:0.52682
# [357]	validation_0-logloss:0.52700
# [358]	validation_0-logloss:0.52670
# [359]	validation_0-logloss:0.52675
# [360]	validation_0-logloss:0.52684
# [361]	validation_0-logloss:0.52653
# [362]	validation_0-logloss:0.52636
# [363]	validation_0-logloss:0.52609
# [364]	validation_0-logloss:0.52615
# [365]	validation_0-logloss:0.52625
# [366]	validation_0-logloss:0.52618
# [367]	validation_0-logloss:0.52603
# [368]	validation_0-logloss:0.52609
# [369]	validation_0-logloss:0.52616
# [370]	validation_0-logloss:0.52617
# [371]	validation_0-logloss:0.52606
# [372]	validation_0-logloss:0.52603
# [373]	validation_0-logloss:0.52614
# [374]	validation_0-logloss:0.52633
# [375]	validation_0-logloss:0.52630
# [376]	validation_0-logloss:0.52649
# [377]	validation_0-logloss:0.52629
# [378]	validation_0-logloss:0.52635
# [379]	validation_0-logloss:0.52618
# [380]	validation_0-logloss:0.52618
# [381]	validation_0-logloss:0.52627
# [382]	validation_0-logloss:0.52641
# [383]	validation_0-logloss:0.52638
# [384]	validation_0-logloss:0.52641
# [385]	validation_0-logloss:0.52647
# [386]	validation_0-logloss:0.52642
# [387]	validation_0-logloss:0.52633
# [388]	validation_0-logloss:0.52627
# [389]	validation_0-logloss:0.52647
# [390]	validation_0-logloss:0.52637
# [391]	validation_0-logloss:0.52632
# [392]	validation_0-logloss:0.52625
# [393]	validation_0-logloss:0.52625
# [394]	validation_0-logloss:0.52624
# [395]	validation_0-logloss:0.52640
# [396]	validation_0-logloss:0.52640
# [397]	validation_0-logloss:0.52636
# [398]	validation_0-logloss:0.52627
# [399]	validation_0-logloss:0.52652
# [400]	validation_0-logloss:0.52650
# [401]	validation_0-logloss:0.52688
# [402]	validation_0-logloss:0.52671
# GridSearchCV(cv=<generator object _BaseKFold.split at 0x7fa4c6933190>,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=1000, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [1.0], 'gamma': [5],
#                          'max_depth': [3], 'min_child_weight': [1],
#                          'subsample': [0.6]})

# %%
grid_basic.best_params_
# Out:
# {'colsample_bytree': 1.0,
#  'gamma': 5,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'subsample': 0.6}

# %% [markdown]
# ### Evaluating Model

# %%
from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix

best_grid_basic = grid_basic.best_estimator_
best_grid_basic_pred = best_grid_basic.predict(x_basic_test)

# Calculate accuracy, precision, recall, f1-score, and kappa score
best_grid_basic_acc = metrics.accuracy_score(y_basic_test, best_grid_basic_pred)
best_grid_basic_prec = metrics.precision_score(y_basic_test, best_grid_basic_pred)
best_grid_basic_rec = metrics.recall_score(y_basic_test, best_grid_basic_pred)
best_grid_basic_f1 = metrics.f1_score(y_basic_test, best_grid_basic_pred)
best_grid_basic_kappa = metrics.cohen_kappa_score(y_basic_test, best_grid_basic_pred)

# Calculate area under curve (AUC)
best_grid_basic_pred_proba = best_grid_basic.predict_proba(x_basic_test)[::,1]
best_grid_basic_fpr, best_grid_basic_tpr, _ = metrics.roc_curve(y_basic_test,  best_grid_basic_pred_proba)
best_grid_basic_auc = metrics.roc_auc_score(y_basic_test, best_grid_basic_pred_proba)

print('Accuracy:', best_grid_basic_acc)
print('Precision:', best_grid_basic_prec)
print('Recall:', best_grid_basic_rec)
print('F1 score:', best_grid_basic_f1)
print('Cohen Kappa Score:', best_grid_basic_kappa)
print('AUC:', best_grid_basic_auc)

# Display confussion matrix
plot_confusion_matrix(best_grid_basic, x_basic_test, y_basic_test)
plt.grid(False)
plt.show()
# Out:
# Accuracy: 0.8166666666666667
# Precision: 1.0
# Recall: 0.21428571428571427
# F1 score: 0.35294117647058826
# Cohen Kappa Score: 0.29487179487179493
# AUC: 0.7282608695652174

# %% [markdown]
# ### Save Model

# %%
import joblib

# Saving model
joblib.dump(best_grid_basic, 'Heart Failure Prediction (Basic).joblib')

def predict_basic(age, anaemia, diabetes, high_blood_pressure, sex, smoking):
    basic_model = joblib.load('Heart Failure Prediction (Basic).joblib') 

    predict_df = pd.DataFrame([[age, anaemia, diabetes, high_blood_pressure, sex, smoking]],
                              columns=['age', 'anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking'])

    pred = basic_model.predict(predict_df)[0]

    if pred==1: return 'True'
    else: return 'False'

print(predict_basic(1, 0, 0, 0, 0, 0))
print(predict_basic(99, 1, 1, 1, 1, 1))
# Out:
# False
# True

# %%
import pickle

# Save model
pickle.dump(best_grid_basic, open('basic.pkl', "wb"))

def predict_basic(age, anaemia, diabetes, high_blood_pressure, sex, smoking):
    basic_model = pickle.load(open('basic.pkl', "rb"))

    predict_df = pd.DataFrame([[age, anaemia, diabetes, high_blood_pressure, sex, smoking]],
                              columns=['age', 'anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking'])

    pred = basic_model.predict(predict_df)[0]

    if pred==1: return 'True'
    else: return 'False'

print(predict_basic(1, 0, 0, 0, 0, 0))
print(predict_basic(99, 1, 1, 1, 1, 1))
# Out:
# False
# True

# %% [markdown]
# ## Advanced Mode

# %% [markdown]
# ### Training Model

# %%
# Select feature
x_adv = df[['age', 'ejection_fraction', 'serum_creatinine', 'serum_sodium']]
y_adv = df['DEATH_EVENT']

# Scale data
from sklearn.preprocessing import StandardScaler
# Copying original dataframe
scaler = StandardScaler()
x_adv_scaled = x_adv.copy()
num_cols = ['age', 'ejection_fraction', 'serum_creatinine', 'serum_sodium']
x_adv_scaled[num_cols] = scaler.fit_transform(x_adv[num_cols])
# x_adv_scaled = scaler.fit_transform(x_adv)

# Split dataset
from sklearn.model_selection import train_test_split
x_adv_train, x_adv_test, y_adv_train, y_adv_test = train_test_split(x_adv_scaled, y_adv, random_state=1, test_size=0.2)

# Train model
from xgboost import XGBClassifier
from xgboost.sklearn import XGBModel
from sklearn.metrics import roc_auc_score, accuracy_score, plot_confusion_matrix
from sklearn.model_selection import StratifiedKFold, GridSearchCV

# params = {
#         'min_child_weight': [1, 5, 10],
#         'gamma': [0.5, 1, 1.5, 2, 5],
#         'subsample': [0.6, 0.8, 1.0],
#         'colsample_bytree': [0.6, 0.8, 1.0],
#         'max_depth': [3, 4, 5]
#         }
params = {
        'min_child_weight': [1],
        'gamma': [2],
        'subsample': [0.6],
        'colsample_bytree': [1.0],
        'max_depth': [4]
        }

xgb_adv = XGBModel(learning_rate=0.01, n_estimators=5000, objective='binary:logistic')

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

grid_adv = GridSearchCV(estimator=xgb, param_grid=params, n_jobs=-1,
                    cv=skf.split(x_adv_train, y_adv_train), verbose=0)

grid_adv.fit(x_adv_train, y_adv_train, early_stopping_rounds=30, eval_set=[(x_adv_test, y_adv_test)])
# Out:
# [0]	validation_0-logloss:0.68954
# [1]	validation_0-logloss:0.68534
# [2]	validation_0-logloss:0.68069
# [3]	validation_0-logloss:0.67662
# [4]	validation_0-logloss:0.67367
# [5]	validation_0-logloss:0.67083
# [6]	validation_0-logloss:0.66718
# [7]	validation_0-logloss:0.66454
# [8]	validation_0-logloss:0.66063
# [9]	validation_0-logloss:0.65643
# [10]	validation_0-logloss:0.65254
# [11]	validation_0-logloss:0.64900
# [12]	validation_0-logloss:0.64572
# [13]	validation_0-logloss:0.64300
# [14]	validation_0-logloss:0.63977
# [15]	validation_0-logloss:0.63601
# [16]	validation_0-logloss:0.63350
# [17]	validation_0-logloss:0.63074
# [18]	validation_0-logloss:0.62713
# [19]	validation_0-logloss:0.62406
# [20]	validation_0-logloss:0.62072
# [21]	validation_0-logloss:0.61811
# [22]	validation_0-logloss:0.61547
# [23]	validation_0-logloss:0.61205
# [24]	validation_0-logloss:0.60875
# [25]	validation_0-logloss:0.60585
# [26]	validation_0-logloss:0.60313
# [27]	validation_0-logloss:0.60029
# [28]	validation_0-logloss:0.59801
# [29]	validation_0-logloss:0.59499
# [30]	validation_0-logloss:0.59213
# [31]	validation_0-logloss:0.58901
# [32]	validation_0-logloss:0.58668
# [33]	validation_0-logloss:0.58449
# [34]	validation_0-logloss:0.58231
# [35]	validation_0-logloss:0.57953
# [36]	validation_0-logloss:0.57692
# [37]	validation_0-logloss:0.57498
# [38]	validation_0-logloss:0.57295
# [39]	validation_0-logloss:0.57106
# [40]	validation_0-logloss:0.56907
# [41]	validation_0-logloss:0.56652
# [42]	validation_0-logloss:0.56411
# [43]	validation_0-logloss:0.56178
# [44]	validation_0-logloss:0.55883
# [45]	validation_0-logloss:0.55675
# [46]	validation_0-logloss:0.55470
# [47]	validation_0-logloss:0.55288
# [48]	validation_0-logloss:0.55041
# [49]	validation_0-logloss:0.54820
# [50]	validation_0-logloss:0.54586
# [51]	validation_0-logloss:0.54312
# [52]	validation_0-logloss:0.54197
# [53]	validation_0-logloss:0.54039
# [54]	validation_0-logloss:0.53841
# [55]	validation_0-logloss:0.53696
# [56]	validation_0-logloss:0.53542
# [57]	validation_0-logloss:0.53428
# [58]	validation_0-logloss:0.53254
# [59]	validation_0-logloss:0.53083
# [60]	validation_0-logloss:0.52869
# [61]	validation_0-logloss:0.52695
# [62]	validation_0-logloss:0.52487
# [63]	validation_0-logloss:0.52326
# [64]	validation_0-logloss:0.52110
# [65]	validation_0-logloss:0.51951
# [66]	validation_0-logloss:0.51785
# [67]	validation_0-logloss:0.51562
# [68]	validation_0-logloss:0.51491
# [69]	validation_0-logloss:0.51466
# [70]	validation_0-logloss:0.51288
# [71]	validation_0-logloss:0.51171
# [72]	validation_0-logloss:0.50997
# [73]	validation_0-logloss:0.50889
# [74]	validation_0-logloss:0.50682
# [75]	validation_0-logloss:0.50504
# [76]	validation_0-logloss:0.50325
# [77]	validation_0-logloss:0.50102
# [78]	validation_0-logloss:0.49989
# [79]	validation_0-logloss:0.49889
# [80]	validation_0-logloss:0.49788
# [81]	validation_0-logloss:0.49671
# [82]	validation_0-logloss:0.49571
# [83]	validation_0-logloss:0.49529
# [84]	validation_0-logloss:0.49421
# [85]	validation_0-logloss:0.49280
# [86]	validation_0-logloss:0.49171
# [87]	validation_0-logloss:0.49029
# [88]	validation_0-logloss:0.48943
# [89]	validation_0-logloss:0.48764
# [90]	validation_0-logloss:0.48672
# [91]	validation_0-logloss:0.48611
# [92]	validation_0-logloss:0.48466
# [93]	validation_0-logloss:0.48273
# [94]	validation_0-logloss:0.48194
# [95]	validation_0-logloss:0.48101
# [96]	validation_0-logloss:0.47999
# [97]	validation_0-logloss:0.47911
# [98]	validation_0-logloss:0.47790
# [99]	validation_0-logloss:0.47743
# [100]	validation_0-logloss:0.47636
# [101]	validation_0-logloss:0.47550
# [102]	validation_0-logloss:0.47512
# [103]	validation_0-logloss:0.47336
# [104]	validation_0-logloss:0.47172
# [105]	validation_0-logloss:0.47085
# [106]	validation_0-logloss:0.46987
# [107]	validation_0-logloss:0.46839
# [108]	validation_0-logloss:0.46698
# [109]	validation_0-logloss:0.46652
# [110]	validation_0-logloss:0.46566
# [111]	validation_0-logloss:0.46456
# [112]	validation_0-logloss:0.46413
# [113]	validation_0-logloss:0.46307
# [114]	validation_0-logloss:0.46200
# [115]	validation_0-logloss:0.46073
# [116]	validation_0-logloss:0.45967
# [117]	validation_0-logloss:0.45831
# [118]	validation_0-logloss:0.45777
# [119]	validation_0-logloss:0.45644
# [120]	validation_0-logloss:0.45512
# [121]	validation_0-logloss:0.45504
# [122]	validation_0-logloss:0.45454
# [123]	validation_0-logloss:0.45376
# [124]	validation_0-logloss:0.45312
# [125]	validation_0-logloss:0.45205
# [126]	validation_0-logloss:0.45114
# [127]	validation_0-logloss:0.45024
# [128]	validation_0-logloss:0.44925
# [129]	validation_0-logloss:0.44879
# [130]	validation_0-logloss:0.44791
# [131]	validation_0-logloss:0.44689
# [132]	validation_0-logloss:0.44598
# [133]	validation_0-logloss:0.44509
# [134]	validation_0-logloss:0.44429
# [135]	validation_0-logloss:0.44333
# [136]	validation_0-logloss:0.44280
# [137]	validation_0-logloss:0.44228
# [138]	validation_0-logloss:0.44189
# [139]	validation_0-logloss:0.44154
# [140]	validation_0-logloss:0.44067
# [141]	validation_0-logloss:0.43994
# [142]	validation_0-logloss:0.43955
# [143]	validation_0-logloss:0.43935
# [144]	validation_0-logloss:0.43935
# [145]	validation_0-logloss:0.43904
# [146]	validation_0-logloss:0.43810
# [147]	validation_0-logloss:0.43810
# [148]	validation_0-logloss:0.43742
# [149]	validation_0-logloss:0.43707
# [150]	validation_0-logloss:0.43631
# [151]	validation_0-logloss:0.43505
# [152]	validation_0-logloss:0.43470
# [153]	validation_0-logloss:0.43411
# [154]	validation_0-logloss:0.43347
# [155]	validation_0-logloss:0.43286
# [156]	validation_0-logloss:0.43260
# [157]	validation_0-logloss:0.43206
# [158]	validation_0-logloss:0.43173
# [159]	validation_0-logloss:0.43122
# [160]	validation_0-logloss:0.43067
# [161]	validation_0-logloss:0.43021
# [162]	validation_0-logloss:0.42993
# [163]	validation_0-logloss:0.42968
# [164]	validation_0-logloss:0.42896
# [165]	validation_0-logloss:0.42801
# [166]	validation_0-logloss:0.42788
# [167]	validation_0-logloss:0.42720
# [168]	validation_0-logloss:0.42696
# [169]	validation_0-logloss:0.42703
# [170]	validation_0-logloss:0.42624
# [171]	validation_0-logloss:0.42611
# [172]	validation_0-logloss:0.42532
# [173]	validation_0-logloss:0.42495
# [174]	validation_0-logloss:0.42413
# [175]	validation_0-logloss:0.42374
# [176]	validation_0-logloss:0.42299
# [177]	validation_0-logloss:0.42190
# [178]	validation_0-logloss:0.42185
# [179]	validation_0-logloss:0.42159
# [180]	validation_0-logloss:0.42109
# [181]	validation_0-logloss:0.42041
# [182]	validation_0-logloss:0.42004
# [183]	validation_0-logloss:0.41933
# [184]	validation_0-logloss:0.41901
# [185]	validation_0-logloss:0.41849
# [186]	validation_0-logloss:0.41785
# [187]	validation_0-logloss:0.41731
# [188]	validation_0-logloss:0.41645
# [189]	validation_0-logloss:0.41585
# [190]	validation_0-logloss:0.41561
# [191]	validation_0-logloss:0.41518
# [192]	validation_0-logloss:0.41502
# [193]	validation_0-logloss:0.41464
# [194]	validation_0-logloss:0.41443
# [195]	validation_0-logloss:0.41487
# [196]	validation_0-logloss:0.41462
# [197]	validation_0-logloss:0.41432
# [198]	validation_0-logloss:0.41338
# [199]	validation_0-logloss:0.41339
# [200]	validation_0-logloss:0.41372
# [201]	validation_0-logloss:0.41336
# [202]	validation_0-logloss:0.41269
# [203]	validation_0-logloss:0.41259
# [204]	validation_0-logloss:0.41236
# [205]	validation_0-logloss:0.41191
# [206]	validation_0-logloss:0.41176
# [207]	validation_0-logloss:0.41129
# [208]	validation_0-logloss:0.41060
# [209]	validation_0-logloss:0.41046
# [210]	validation_0-logloss:0.40996
# [211]	validation_0-logloss:0.40989
# [212]	validation_0-logloss:0.40978
# [213]	validation_0-logloss:0.40883
# [214]	validation_0-logloss:0.40861
# [215]	validation_0-logloss:0.40799
# [216]	validation_0-logloss:0.40800
# [217]	validation_0-logloss:0.40789
# [218]	validation_0-logloss:0.40765
# [219]	validation_0-logloss:0.40774
# [220]	validation_0-logloss:0.40755
# [221]	validation_0-logloss:0.40687
# [222]	validation_0-logloss:0.40675
# [223]	validation_0-logloss:0.40634
# [224]	validation_0-logloss:0.40616
# [225]	validation_0-logloss:0.40565
# [226]	validation_0-logloss:0.40538
# [227]	validation_0-logloss:0.40481
# [228]	validation_0-logloss:0.40459
# [229]	validation_0-logloss:0.40458
# [230]	validation_0-logloss:0.40390
# [231]	validation_0-logloss:0.40377
# [232]	validation_0-logloss:0.40360
# [233]	validation_0-logloss:0.40310
# [234]	validation_0-logloss:0.40297
# [235]	validation_0-logloss:0.40284
# [236]	validation_0-logloss:0.40267
# [237]	validation_0-logloss:0.40211
# [238]	validation_0-logloss:0.40196
# [239]	validation_0-logloss:0.40185
# [240]	validation_0-logloss:0.40151
# [241]	validation_0-logloss:0.40157
# [242]	validation_0-logloss:0.40112
# [243]	validation_0-logloss:0.40091
# [244]	validation_0-logloss:0.40042
# [245]	validation_0-logloss:0.39993
# [246]	validation_0-logloss:0.39956
# [247]	validation_0-logloss:0.39899
# [248]	validation_0-logloss:0.39854
# [249]	validation_0-logloss:0.39813
# [250]	validation_0-logloss:0.39782
# [251]	validation_0-logloss:0.39750
# [252]	validation_0-logloss:0.39667
# [253]	validation_0-logloss:0.39657
# [254]	validation_0-logloss:0.39621
# [255]	validation_0-logloss:0.39581
# [256]	validation_0-logloss:0.39548
# [257]	validation_0-logloss:0.39542
# [258]	validation_0-logloss:0.39530
# [259]	validation_0-logloss:0.39505
# [260]	validation_0-logloss:0.39506
# [261]	validation_0-logloss:0.39471
# [262]	validation_0-logloss:0.39455
# [263]	validation_0-logloss:0.39427
# [264]	validation_0-logloss:0.39394
# [265]	validation_0-logloss:0.39367
# [266]	validation_0-logloss:0.39364
# [267]	validation_0-logloss:0.39343
# [268]	validation_0-logloss:0.39352
# [269]	validation_0-logloss:0.39357
# [270]	validation_0-logloss:0.39317
# [271]	validation_0-logloss:0.39304
# [272]	validation_0-logloss:0.39298
# [273]	validation_0-logloss:0.39277
# [274]	validation_0-logloss:0.39224
# [275]	validation_0-logloss:0.39187
# [276]	validation_0-logloss:0.39205
# [277]	validation_0-logloss:0.39176
# [278]	validation_0-logloss:0.39154
# [279]	validation_0-logloss:0.39127
# [280]	validation_0-logloss:0.39082
# [281]	validation_0-logloss:0.39066
# [282]	validation_0-logloss:0.39006
# [283]	validation_0-logloss:0.39034
# [284]	validation_0-logloss:0.39039
# [285]	validation_0-logloss:0.39015
# [286]	validation_0-logloss:0.38997
# [287]	validation_0-logloss:0.38947
# [288]	validation_0-logloss:0.38925
# [289]	validation_0-logloss:0.38922
# [290]	validation_0-logloss:0.38900
# [291]	validation_0-logloss:0.38887
# [292]	validation_0-logloss:0.38902
# [293]	validation_0-logloss:0.38886
# [294]	validation_0-logloss:0.38835
# [295]	validation_0-logloss:0.38822
# [296]	validation_0-logloss:0.38806
# [297]	validation_0-logloss:0.38758
# [298]	validation_0-logloss:0.38745
# [299]	validation_0-logloss:0.38749
# [300]	validation_0-logloss:0.38761
# [301]	validation_0-logloss:0.38774
# [302]	validation_0-logloss:0.38678
# [303]	validation_0-logloss:0.38660
# [304]	validation_0-logloss:0.38626
# [305]	validation_0-logloss:0.38634
# [306]	validation_0-logloss:0.38611
# [307]	validation_0-logloss:0.38599
# [308]	validation_0-logloss:0.38556
# [309]	validation_0-logloss:0.38503
# [310]	validation_0-logloss:0.38500
# [311]	validation_0-logloss:0.38507
# [312]	validation_0-logloss:0.38473
# [313]	validation_0-logloss:0.38476
# [314]	validation_0-logloss:0.38434
# [315]	validation_0-logloss:0.38445
# [316]	validation_0-logloss:0.38479
# [317]	validation_0-logloss:0.38468
# [318]	validation_0-logloss:0.38494
# [319]	validation_0-logloss:0.38475
# [320]	validation_0-logloss:0.38461
# [321]	validation_0-logloss:0.38387
# [322]	validation_0-logloss:0.38376
# [323]	validation_0-logloss:0.38323
# [324]	validation_0-logloss:0.38269
# [325]	validation_0-logloss:0.38250
# [326]	validation_0-logloss:0.38213
# [327]	validation_0-logloss:0.38167
# [328]	validation_0-logloss:0.38160
# [329]	validation_0-logloss:0.38121
# [330]	validation_0-logloss:0.38134
# [331]	validation_0-logloss:0.38151
# [332]	validation_0-logloss:0.38167
# [333]	validation_0-logloss:0.38174
# [334]	validation_0-logloss:0.38195
# [335]	validation_0-logloss:0.38198
# [336]	validation_0-logloss:0.38215
# [337]	validation_0-logloss:0.38166
# [338]	validation_0-logloss:0.38158
# [339]	validation_0-logloss:0.38132
# [340]	validation_0-logloss:0.38155
# [341]	validation_0-logloss:0.38155
# [342]	validation_0-logloss:0.38158
# [343]	validation_0-logloss:0.38161
# [344]	validation_0-logloss:0.38122
# [345]	validation_0-logloss:0.38101
# [346]	validation_0-logloss:0.38066
# [347]	validation_0-logloss:0.38011
# [348]	validation_0-logloss:0.37952
# [349]	validation_0-logloss:0.37951
# [350]	validation_0-logloss:0.37932
# [351]	validation_0-logloss:0.37950
# [352]	validation_0-logloss:0.37921
# [353]	validation_0-logloss:0.37906
# [354]	validation_0-logloss:0.37916
# [355]	validation_0-logloss:0.37879
# [356]	validation_0-logloss:0.37862
# [357]	validation_0-logloss:0.37931
# [358]	validation_0-logloss:0.37934
# [359]	validation_0-logloss:0.37921
# [360]	validation_0-logloss:0.37912
# [361]	validation_0-logloss:0.37864
# [362]	validation_0-logloss:0.37840
# [363]	validation_0-logloss:0.37808
# [364]	validation_0-logloss:0.37798
# [365]	validation_0-logloss:0.37812
# [366]	validation_0-logloss:0.37772
# [367]	validation_0-logloss:0.37777
# [368]	validation_0-logloss:0.37705
# [369]	validation_0-logloss:0.37702
# [370]	validation_0-logloss:0.37703
# [371]	validation_0-logloss:0.37695
# [372]	validation_0-logloss:0.37669
# [373]	validation_0-logloss:0.37662
# [374]	validation_0-logloss:0.37697
# [375]	validation_0-logloss:0.37637
# [376]	validation_0-logloss:0.37646
# [377]	validation_0-logloss:0.37616
# [378]	validation_0-logloss:0.37606
# [379]	validation_0-logloss:0.37597
# [380]	validation_0-logloss:0.37604
# [381]	validation_0-logloss:0.37570
# [382]	validation_0-logloss:0.37576
# [383]	validation_0-logloss:0.37524
# [384]	validation_0-logloss:0.37525
# [385]	validation_0-logloss:0.37541
# [386]	validation_0-logloss:0.37580
# [387]	validation_0-logloss:0.37537
# [388]	validation_0-logloss:0.37491
# [389]	validation_0-logloss:0.37502
# [390]	validation_0-logloss:0.37496
# [391]	validation_0-logloss:0.37493
# [392]	validation_0-logloss:0.37503
# [393]	validation_0-logloss:0.37510
# [394]	validation_0-logloss:0.37541
# [395]	validation_0-logloss:0.37553
# [396]	validation_0-logloss:0.37544
# [397]	validation_0-logloss:0.37525
# [398]	validation_0-logloss:0.37519
# [399]	validation_0-logloss:0.37494
# [400]	validation_0-logloss:0.37494
# [401]	validation_0-logloss:0.37505
# [402]	validation_0-logloss:0.37479
# [403]	validation_0-logloss:0.37477
# [404]	validation_0-logloss:0.37428
# [405]	validation_0-logloss:0.37420
# [406]	validation_0-logloss:0.37400
# [407]	validation_0-logloss:0.37429
# [408]	validation_0-logloss:0.37454
# [409]	validation_0-logloss:0.37448
# [410]	validation_0-logloss:0.37455
# [411]	validation_0-logloss:0.37447
# [412]	validation_0-logloss:0.37437
# [413]	validation_0-logloss:0.37446
# [414]	validation_0-logloss:0.37443
# [415]	validation_0-logloss:0.37469
# [416]	validation_0-logloss:0.37487
# [417]	validation_0-logloss:0.37495
# [418]	validation_0-logloss:0.37463
# [419]	validation_0-logloss:0.37412
# [420]	validation_0-logloss:0.37425
# [421]	validation_0-logloss:0.37437
# [422]	validation_0-logloss:0.37453
# [423]	validation_0-logloss:0.37431
# [424]	validation_0-logloss:0.37394
# [425]	validation_0-logloss:0.37395
# [426]	validation_0-logloss:0.37395
# [427]	validation_0-logloss:0.37419
# [428]	validation_0-logloss:0.37413
# [429]	validation_0-logloss:0.37396
# [430]	validation_0-logloss:0.37376
# [431]	validation_0-logloss:0.37376
# [432]	validation_0-logloss:0.37385
# [433]	validation_0-logloss:0.37407
# [434]	validation_0-logloss:0.37429
# [435]	validation_0-logloss:0.37433
# [436]	validation_0-logloss:0.37388
# [437]	validation_0-logloss:0.37385
# [438]	validation_0-logloss:0.37381
# [439]	validation_0-logloss:0.37363
# [440]	validation_0-logloss:0.37360
# [441]	validation_0-logloss:0.37354
# [442]	validation_0-logloss:0.37336
# [443]	validation_0-logloss:0.37331
# [444]	validation_0-logloss:0.37372
# [445]	validation_0-logloss:0.37391
# [446]	validation_0-logloss:0.37376
# [447]	validation_0-logloss:0.37387
# [448]	validation_0-logloss:0.37410
# [449]	validation_0-logloss:0.37389
# [450]	validation_0-logloss:0.37374
# [451]	validation_0-logloss:0.37391
# [452]	validation_0-logloss:0.37335
# [453]	validation_0-logloss:0.37341
# [454]	validation_0-logloss:0.37354
# [455]	validation_0-logloss:0.37353
# [456]	validation_0-logloss:0.37352
# [457]	validation_0-logloss:0.37330
# [458]	validation_0-logloss:0.37338
# [459]	validation_0-logloss:0.37302
# [460]	validation_0-logloss:0.37302
# [461]	validation_0-logloss:0.37314
# [462]	validation_0-logloss:0.37288
# [463]	validation_0-logloss:0.37282
# [464]	validation_0-logloss:0.37293
# [465]	validation_0-logloss:0.37284
# [466]	validation_0-logloss:0.37282
# [467]	validation_0-logloss:0.37260
# [468]	validation_0-logloss:0.37254
# [469]	validation_0-logloss:0.37272
# [470]	validation_0-logloss:0.37264
# [471]	validation_0-logloss:0.37260
# [472]	validation_0-logloss:0.37275
# [473]	validation_0-logloss:0.37275
# [474]	validation_0-logloss:0.37242
# [475]	validation_0-logloss:0.37221
# [476]	validation_0-logloss:0.37217
# [477]	validation_0-logloss:0.37211
# [478]	validation_0-logloss:0.37194
# [479]	validation_0-logloss:0.37182
# [480]	validation_0-logloss:0.37182
# [481]	validation_0-logloss:0.37171
# [482]	validation_0-logloss:0.37190
# [483]	validation_0-logloss:0.37183
# [484]	validation_0-logloss:0.37161
# [485]	validation_0-logloss:0.37156
# [486]	validation_0-logloss:0.37143
# [487]	validation_0-logloss:0.37138
# [488]	validation_0-logloss:0.37146
# [489]	validation_0-logloss:0.37146
# [490]	validation_0-logloss:0.37129
# [491]	validation_0-logloss:0.37154
# [492]	validation_0-logloss:0.37144
# [493]	validation_0-logloss:0.37161
# [494]	validation_0-logloss:0.37159
# [495]	validation_0-logloss:0.37156
# [496]	validation_0-logloss:0.37153
# [497]	validation_0-logloss:0.37161
# [498]	validation_0-logloss:0.37125
# [499]	validation_0-logloss:0.37128
# [500]	validation_0-logloss:0.37128
# [501]	validation_0-logloss:0.37122
# [502]	validation_0-logloss:0.37100
# [503]	validation_0-logloss:0.37110
# [504]	validation_0-logloss:0.37123
# [505]	validation_0-logloss:0.37147
# [506]	validation_0-logloss:0.37182
# [507]	validation_0-logloss:0.37190
# [508]	validation_0-logloss:0.37217
# [509]	validation_0-logloss:0.37207
# [510]	validation_0-logloss:0.37212
# [511]	validation_0-logloss:0.37227
# [512]	validation_0-logloss:0.37227
# [513]	validation_0-logloss:0.37172
# [514]	validation_0-logloss:0.37151
# [515]	validation_0-logloss:0.37199
# [516]	validation_0-logloss:0.37179
# [517]	validation_0-logloss:0.37153
# [518]	validation_0-logloss:0.37125
# [519]	validation_0-logloss:0.37135
# [520]	validation_0-logloss:0.37096
# [521]	validation_0-logloss:0.37113
# [522]	validation_0-logloss:0.37100
# [523]	validation_0-logloss:0.37105
# [524]	validation_0-logloss:0.37103
# [525]	validation_0-logloss:0.37054
# [526]	validation_0-logloss:0.37054
# [527]	validation_0-logloss:0.37100
# [528]	validation_0-logloss:0.37084
# [529]	validation_0-logloss:0.37120
# [530]	validation_0-logloss:0.37117
# [531]	validation_0-logloss:0.37132
# [532]	validation_0-logloss:0.37146
# [533]	validation_0-logloss:0.37165
# [534]	validation_0-logloss:0.37175
# [535]	validation_0-logloss:0.37188
# [536]	validation_0-logloss:0.37244
# [537]	validation_0-logloss:0.37247
# [538]	validation_0-logloss:0.37214
# [539]	validation_0-logloss:0.37217
# [540]	validation_0-logloss:0.37237
# [541]	validation_0-logloss:0.37227
# [542]	validation_0-logloss:0.37223
# [543]	validation_0-logloss:0.37218
# [544]	validation_0-logloss:0.37218
# [545]	validation_0-logloss:0.37209
# [546]	validation_0-logloss:0.37194
# [547]	validation_0-logloss:0.37208
# [548]	validation_0-logloss:0.37246
# [549]	validation_0-logloss:0.37227
# [550]	validation_0-logloss:0.37232
# [551]	validation_0-logloss:0.37223
# [552]	validation_0-logloss:0.37276
# [553]	validation_0-logloss:0.37292
# [554]	validation_0-logloss:0.37300
# [555]	validation_0-logloss:0.37288
# GridSearchCV(cv=<generator object _BaseKFold.split at 0x7fa4c225aba0>,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=1000, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [1.0], 'gamma': [2],
#                          'max_depth': [4], 'min_child_weight': [1],
#                          'subsample': [0.6]})

# %%
grid_adv.best_params_
# Out:
# {'colsample_bytree': 1.0,
#  'gamma': 2,
#  'max_depth': 4,
#  'min_child_weight': 1,
#  'subsample': 0.6}

# %% [markdown]
# ### Evaluating Model

# %%
from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix

best_grid_adv = grid_adv.best_estimator_
best_grid_adv_pred = best_grid_adv.predict(x_adv_test)

# Calculate accuracy, precision, recall, f1-score, and kappa score
best_grid_adv_acc = metrics.accuracy_score(y_adv_test, best_grid_adv_pred)
best_grid_adv_prec = metrics.precision_score(y_adv_test, best_grid_adv_pred)
best_grid_adv_rec = metrics.recall_score(y_adv_test, best_grid_adv_pred)
best_grid_adv_f1 = metrics.f1_score(y_adv_test, best_grid_adv_pred)
best_grid_adv_kappa = metrics.cohen_kappa_score(y_adv_test, best_grid_adv_pred)

# Calculate area under curve (AUC)
best_grid_adv_pred_proba = best_grid_adv.predict_proba(x_adv_test)[::,1]
best_grid_adv_fpr, best_grid_adv_tpr, _ = metrics.roc_curve(y_adv_test,  best_grid_adv_pred_proba)
best_grid_adv_auc = metrics.roc_auc_score(y_adv_test, best_grid_adv_pred_proba)

print('Accuracy:', best_grid_adv_acc)
print('Precision:', best_grid_adv_prec)
print('Recall:', best_grid_adv_rec)
print('F1 score:', best_grid_adv_f1)
print('Cohen Kappa Score:', best_grid_adv_kappa)
print('AUC:', best_grid_adv_auc)

# Display confussion matrix
plot_confusion_matrix(best_grid_adv, x_adv_test, y_adv_test)
plt.grid(False)
plt.show()
# Out:
# Accuracy: 0.85
# Precision: 0.6923076923076923
# Recall: 0.6428571428571429
# F1 score: 0.6666666666666666
# Cohen Kappa Score: 0.5700636942675159
# AUC: 0.8990683229813665

# %% [markdown]
# ### Save Model

# %%
import joblib

# Saving model
joblib.dump(best_grid_adv, 'Heart Failure Prediction (Advanced).joblib')

def predict_advanced(age, ejection_fraction, serum_creatinine, serum_sodium):
    advanced_model = joblib.load('Heart Failure Prediction (Advanced).joblib') 

    predict_df = pd.DataFrame([[age, ejection_fraction, serum_creatinine, serum_sodium]],
                              columns=[['age', 'ejection_fraction', 'serum_creatinine', 'serum_sodium']])

    pred = advanced_model.predict(predict_df)[0]

    if pred==1: return 'True'
    else: return 'False'

print(predict_advanced(21, 60, 1.5, 90))
print(predict_advanced(12, 30, 2.5, 120))
# Out:
# True
# True

# %%
import pickle

# Save model
pickle.dump(best_grid_adv, open('advanced.pkl', "wb"))

def predict_advanced(age, ejection_fraction, serum_creatinine, serum_sodium):
    advanced_model = pickle.load(open('advanced.pkl', "rb"))

    predict_df = pd.DataFrame([[age, ejection_fraction, serum_creatinine, serum_sodium]],
                              columns=[['age', 'ejection_fraction', 'serum_creatinine', 'serum_sodium']])

    pred = advanced_model.predict(predict_df)[0]

    if pred==1: return 'True'
    else: return 'False'

print(predict_advanced(21, 60, 1.5, 90))
print(predict_advanced(12, 30, 2.5, 120))
# Out:
# True
# True
